# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files

mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")

# Display the data table for preview
merge_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
total_mice = merge_df["Mouse ID"].nunique()
print(total_mice)
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dup = merge_df[merge_df.duplicated(subset=["Mouse ID","Timepoint"], keep=False)]
dupname = dup["Mouse ID"].value_counts()
dupname
# Out:
# g989    10
# Name: Mouse ID, dtype: int64

# %%
# Optional: Get all the data for the duplicate mouse ID. 
merge_df[merge_df.duplicated(subset=["Mouse ID", "Timepoint"], keep=False)]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = merge_df.loc[merge_df["Mouse ID"] != "g989"]
clean_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
clean_mice_df = clean_df["Mouse ID"].nunique()
clean_mice_df
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

# Variables for statistical information
mean = clean_df[["Drug Regimen", "Tumor Volume (mm3)"]].groupby("Drug Regimen").mean()
median = clean_df[["Drug Regimen", "Tumor Volume (mm3)"]].groupby("Drug Regimen").median()
variance = clean_df[["Drug Regimen", "Tumor Volume (mm3)"]].groupby("Drug Regimen").var()
standard = clean_df[["Drug Regimen", "Tumor Volume (mm3)"]].groupby("Drug Regimen").std()
SEM = clean_df[["Drug Regimen", "Tumor Volume (mm3)"]].groupby("Drug Regimen").sem()

groupby_df = clean_df.groupby(["Drug Regimen"]).count()

summary_df = pd.DataFrame(groupby_df)
summary_df["mean"] = mean
summary_df["median"] = median
summary_df["var"] = variance
summary_df["std"] = standard
summary_df["sem"] = SEM
summary_stat_df = summary_df[["mean", "median", "var", "std", "sem"]]
summary_stat_df
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line
clean_agg_df = clean_df[["Drug Regimen", "Tumor Volume (mm3)"]].groupby("Drug Regimen").agg({"Tumor Volume (mm3)": ['mean', 'median', 'var', 'std', 'sem']})
clean_agg_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
# clean_df 
x = clean_df["Drug Regimen"].unique()

z = clean_df.groupby("Drug Regimen").count()["Mouse ID"] #possibly need to use '.nunique' instead of count

ax = z.plot.bar(rot = 50)
plt.title("Measurments by Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Measurements")
plt.show()
# KEEP
# print(clean_df["Drug Regimen"].unique.to_string(index=False))
# plt.bar(x,z,facecolor="red", alpha=0.75, align="center")
# plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
# **double check sorting here**
plt.bar(x,z)
plt.xticks(x, clean_df["Drug Regimen"].unique(), rotation=60)
plt.title("Measurements by Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Measurements")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_group_df = clean_df.groupby(["Sex"]).count()
gender_df = pd.DataFrame(gender_group_df)
summary_gender_df = gender_df.drop(columns=["Drug Regimen", "Age_months", "Weight (g)", "Timepoint", "Tumor Volume (mm3)", "Metastatic Sites"])
summary_gender_df
plot = summary_gender_df.plot.pie(subplots=True, figsize=(5, 5), autopct="%1.1f%%", shadow=True, startangle=40, explode=(0,0.1), title="Gender Comparison of Mice")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = clean_df["Sex"].unique()
explode = (0.1, 0)
plt.pie(clean_df["Sex"].value_counts(),labels=labels, autopct="%1.1f%%",explode=explode, shadow=True, startangle=140)
plt.title("Gender Comparison of Mice",bbox={'facecolor':'0.6', 'pad':5})
plt.ylabel("Gender Percentage")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
# max_tp_df = pd.DataFrame({"Last Timepoint": max_tp})

filt_clean_df = clean_df[(clean_df["Drug Regimen"] == "Capomulin")|
                         (clean_df["Drug Regimen"] == "Ramicane") |
                         (clean_df["Drug Regimen"] == "Infubinol") |
                         (clean_df["Drug Regimen"] == "Ceftamin") ]
filt_clean_df = filt_clean_df[["Mouse ID", "Drug Regimen", "Timepoint", "Tumor Volume (mm3)"]].groupby(["Mouse ID", "Drug Regimen"]).max()
reseti_filtclean_df = filt_clean_df.reset_index()
reseti_filtclean_df.head(20)

# max_tp = filt_clean_df["Timepoint"].max()
# print(max_tp)
# max_tp_df = pd.DataFrame({"Last Timepoint":max_tp})
# max_tp_df
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# new = pd.merge(clean_df, max_tp_df, on="Mouse ID")
# new_sort = new.sort_values(by=["Mouse ID","Timepoint"])
# new_sort
# Out:
#    Mouse ID Drug Regimen  Timepoint  Tumor Volume (mm3)
# 0      a203    Infubinol         45           67.973419
# 1      a251    Infubinol         45           65.525743
# 2      a275     Ceftamin         45           62.999356
# 3      a411     Ramicane         45           45.466677
# 4      a444     Ramicane         45           45.000000
# 5      a520     Ramicane         45           45.000000
# 6      a577    Infubinol         30           57.031862
# 7      a644     Ramicane         45           46.910892
# 8      a685    Infubinol         45           66.083066
# 9      b128    Capomulin         45           45.651331
# 10     b447     Ceftamin          0           45.000000
# 11     b487     Ceftamin         25           56.057749
# 12     b742    Capomulin         45           45.000000
# 13     b759     Ceftamin         30           55.742829
# 14     c139    Infubinol         45           72.226731
# 15     c326    Infubinol          5           45.000000
# 16     c458     Ramicane         30           45.722279
# 17     c758     Ramicane         45           46.940945
# 18     c895    Infubinol         30           60.969711
# 19     d251     Ramicane         45           45.000000

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
# for treatment in clean_df["Drug Regimen"].unique():
#     treatments.append(treatment)

# Create empty list to fill with tumor vol data (for plotting)
tumor_sizes = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
#Quartiles
for treatment in treatments:
    quartiles = filt_clean_df[treatment].quantile([.25,.5,.75]).round(2)
    print(quartiles)

#IQR

#Outlier Boundaries

#Potential Outliers
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Capomulin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-c63c1e4fe120> in <module>
#      10 #Quartiles
#      11 for treatment in treatments:
# ---> 12     quartiles = filt_clean_df[treatment].quantile([.25,.5,.75]).round(2)
#      13     print(quartiles)
#      14 #     lowerq = quartiles[0.25].round(2)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Capomulin'

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
